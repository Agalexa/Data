# %%
import pandas as pd 
from matplotlib import pyplot as plt

confirm_df = pd.read_csv("COVID-19/csse_covid_19_data/csse_covid_19_time_series/time_series_19-covid-confirmed.csv")
korea_df = pd.read_csv("coronavirusdataset/PatientInfo.csv")

ja_df = confirm_df [ confirm_df['Country/Region'] == "Japan"]
ch_df = confirm_df [ confirm_df['Country/Region'] == "China"]
us_df = confirm_df [ confirm_df['Country/Region'] == "US"]
it_df = confirm_df [ confirm_df['Country/Region'] == "Italy"]
sp_df = confirm_df [ confirm_df['Country/Region'] == "Spain"]
uk_df = confirm_df [ confirm_df['Country/Region'] == "United Kingdom"]
th_df = confirm_df [ confirm_df['Country/Region'] == "Thailand"]
ge_df = confirm_df [ confirm_df['Country/Region'] == "Germany"]

ja_ff = ja_df[ja_df.columns[4:64]]
ch_ff = ch_df[ch_df.columns[4:64]]
us_ff = us_df[us_df.columns[4:64]]
it_ff = it_df[it_df.columns[4:64]]
sp_ff = sp_df[sp_df.columns[4:64]]
uk_ff = uk_df[uk_df.columns[4:64]]
th_ff = th_df[th_df.columns[4:64]]
ge_ff = ge_df[ge_df.columns[4:64]]


ja_list = []
ch_list = []
us_list = []
it_list = []
sp_list = []
uk_list = []
th_list = []
ge_list = []

for x in ja_ff:
    ja_list.append(ja_df[x].sum())
    
for x in ch_ff:
    ch_list.append(ch_df[x].sum())
    
for x in us_ff:
    us_list.append(us_df[x].sum())

for x in it_ff:
    it_list.append(it_df[x].sum())
    
for x in sp_ff:
    sp_list.append(sp_df[x].sum())
    
for x in uk_ff:
    uk_list.append(uk_df[x].sum())
    
for x in th_ff:
    th_list.append(th_df[x].sum())
    
for x in ge_ff:
    ge_list.append(ge_df[x].sum())

# %%
plt.title('Covid-19 cases Japan ')
plt.xlabel('days')
plt.ylabel('infected')
plt.plot(confirm_df.columns[4:64],ja_list)

# %%
plt.title('Covid-19 cases China ')
plt.xlabel('days')
plt.ylabel('infected')
plt.plot(confirm_df.columns[4:64],ch_list)

# %%
plt.title('Covid-19 cases US ')
plt.xlabel('days')
plt.ylabel('infected')
plt.plot(confirm_df.columns[4:64],us_list)

# %%
plt.title('Covid-19 cases Italy ')
plt.xlabel('days')
plt.ylabel('infected')
plt.plot(confirm_df.columns[4:64],it_list)

# %%
plt.title('Covid-19 cases Spain ')
plt.xlabel('days')
plt.ylabel('infected')
plt.plot(confirm_df.columns[4:64],sp_list)

# %%
plt.title('Covid-19 cases UK ')
plt.xlabel('days')
plt.ylabel('infected')
plt.plot(confirm_df.columns[4:64],uk_list)

# %%
plt.title('Covid-19 cases Thailand ')
plt.xlabel('days')
plt.ylabel('infected')
plt.plot(confirm_df.columns[4:64],th_list)

# %%
plt.title('Covid-19 cases Germany ')
plt.xlabel('days')
plt.ylabel('infected')
plt.plot(confirm_df.columns[4:64],ge_list)

# %%
plt.title('Covid-19 cases Germany vs US')
plt.xlabel('days')
plt.ylabel('infected')
plt.plot(confirm_df.columns[4:64],ge_list)
plt.plot(confirm_df.columns[4:64],us_list)
plt.legend(['Germany','US'])

# %%
plt.title('Covid-19 cases Italy vs US')
plt.xlabel('days')
plt.ylabel('infected')
plt.plot(confirm_df.columns[4:64],it_list)
plt.plot(confirm_df.columns[4:64],us_list)
plt.legend(['Italy','US'])

# %%
plt.title('Covid-19 cases Spain vs US')
plt.xlabel('days')
plt.ylabel('infected')
plt.plot(confirm_df.columns[4:64],sp_list)
plt.plot(confirm_df.columns[4:64],us_list)
plt.legend(['Spain','US'])

# %%
plt.title('Covid-19 cases China vs US')
plt.xlabel('days')
plt.ylabel('infected')
plt.plot(confirm_df.columns[4:64],ch_list)
plt.plot(confirm_df.columns[4:64],us_list)
plt.legend(['China','US'])

# %%
plt.title('Covid-19 cases Japan vs US')
plt.xlabel('days')
plt.ylabel('infected')
plt.plot(confirm_df.columns[4:64],ja_list)
plt.plot(confirm_df.columns[4:64],us_list)
plt.legend(['Japan','US'])

# %%
#The above graph really sums up the difference in what an effective governmental response can mean.
