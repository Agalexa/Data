# %%
'''
~WRITE UP~
    The goal of this data analysis project is to examine the infection rate of various countries with respects 
    to the covid - 19 virus to better understand the significance of governmental response and preparedness
    in preventing the spread of infection. 
    I will be looking at graphs and data to determine things like rates of change, total infection rate and the relationship
    between these two variables. 
    One thing to note about growth when related to infectious diseases. The rate at which people become infected
    is almost always going to be exponential. As can be observed from the graphs below, basically all of the countries
    follow this distribution pattern, with a small amount of cases at first with a small rate of change, to faster 
    and faster rates of change balloning the infected population.
    
    Lets compare Japan and South Korea first...
    
    As you can see from the graph below Japan has done a splendid job of delaying the exponential explosion of growth
    that is bound to happen with these types of infectious pandemics. 
    
   
   If you compare the US and China, you can see that the growth rate of the US is greater than China, with a steeper curve
    Also, if you compare the US to Italy, two nations that are woefully underprepared for this pandemic, their growth curves are
    very similiar with the US actually having a steeper curve. 
    
    Thailand and Japan are probably the two best examples of countries effectively "flattening the curve"
    which slows the onset of exponential growth.
'''



import pandas as pd 
from matplotlib import pyplot as plt

confirm_df = pd.read_csv("COVID-19/csse_covid_19_data/csse_covid_19_time_series/time_series_19-covid-confirmed.csv")
country_df = pd.read_csv('info/info.csv')

ja_df = confirm_df [ confirm_df['Country/Region'] == "Japan"]
ch_df = confirm_df [ confirm_df['Country/Region'] == "China"]
us_df = confirm_df [ confirm_df['Country/Region'] == "US"]
it_df = confirm_df [ confirm_df['Country/Region'] == "Italy"]
sp_df = confirm_df [ confirm_df['Country/Region'] == "Spain"]
uk_df = confirm_df [ confirm_df['Country/Region'] == "United Kingdom"]
th_df = confirm_df [ confirm_df['Country/Region'] == "Thailand"]
ge_df = confirm_df [ confirm_df['Country/Region'] == "Germany"]
sk_df = confirm_df [ confirm_df['Country/Region'] == "Korea"]

y = len(confirm_df.columns)- 1
dates = confirm_df.columns[4:y]

ja_ff = ja_df[ja_df.columns[4:y]]
ch_ff = ch_df[ch_df.columns[4:y]]
us_ff = us_df[us_df.columns[4:y]]
it_ff = it_df[it_df.columns[4:y]]
sp_ff = sp_df[sp_df.columns[4:y]]
uk_ff = uk_df[uk_df.columns[4:y]]
th_ff = th_df[th_df.columns[4:y]]
ge_ff = ge_df[ge_df.columns[4:y]]
sk_ff = sk_df[ge_df.columns[4:y]]


ja_list = []
ch_list = []
us_list = []
it_list = []
sp_list = []
uk_list = []
th_list = []
ge_list = []
sk_list = []

for x in ja_ff:
    ja_list.append(ja_df[x].sum())
    
for x in ch_ff:
    ch_list.append(ch_df[x].sum())
    
for x in us_ff:
    us_list.append(us_df[x].sum())

for x in it_ff:
    it_list.append(it_df[x].sum())
    
for x in sp_ff:
    sp_list.append(sp_df[x].sum())
    
for x in uk_ff:
    uk_list.append(uk_df[x].sum())
    
for x in th_ff:
    th_list.append(th_df[x].sum())
    
for x in ge_ff:
    ge_list.append(ge_df[x].sum())
    
for x in sk_ff:
    sk_list.append(sk_df[x].sum())

# %%
plt.title('Covid-19 cases Japan vs SK')
plt.xlabel('days')
plt.ylabel('infected')
plt.plot(confirm_df.columns[4:y],ja_list)
plt.plot(confirm_df.columns[4:y],sk_list)
plt.legend(['Japan','SK'])
plt.show()

# %%
plt.title('Covid-19 cases South Korea ')
plt.xlabel('days')
plt.ylabel('infected')
plt.plot(confirm_df.columns[4:y],sk_list)

# %%
plt.title('Covid-19 cases Japan ')
plt.xlabel('days')
plt.ylabel('infected')
plt.plot(confirm_df.columns[4:y],ja_list)

# %%
plt.title('Covid-19 cases China ')
plt.xlabel('days')
plt.ylabel('infected')
plt.plot(confirm_df.columns[4:y],ch_list)

# %%
plt.title('Covid-19 cases US ')
plt.xlabel('days')
plt.ylabel('infected')
plt.plot(confirm_df.columns[4:y],us_list)

# %%
plt.title('Covid-19 cases Italy ')
plt.xlabel('days')
plt.ylabel('infected')
plt.plot(confirm_df.columns[4:y],it_list)

# %%
plt.title('Covid-19 cases Spain ')
plt.xlabel('days')
plt.ylabel('infected')
plt.plot(confirm_df.columns[4:y],sp_list)

# %%
plt.title('Covid-19 cases UK ')
plt.xlabel('days')
plt.ylabel('infected')
plt.plot(confirm_df.columns[4:y],uk_list)

# %%
plt.title('Covid-19 cases Thailand ')
plt.xlabel('days')
plt.ylabel('infected')
plt.plot(confirm_df.columns[4:y],th_list)

# %%
plt.title('Covid-19 cases Germany ')
plt.xlabel('days')
plt.ylabel('infected')
plt.plot(confirm_df.columns[4:y],ge_list)

# %%
plt.title('Covid-19 cases Germany vs US')
plt.xlabel('days')
plt.ylabel('infected')
plt.plot(confirm_df.columns[4:y],ge_list)
plt.plot(confirm_df.columns[4:y],us_list)
plt.legend(['Germany','US'])

# %%
plt.title('Covid-19 cases Italy vs US')
plt.xlabel('days')
plt.ylabel('infected')
plt.plot(confirm_df.columns[4:y],it_list)
plt.plot(confirm_df.columns[4:y],us_list)
plt.legend(['Italy','US'])

# %%
plt.title('Covid-19 cases Spain vs US')
plt.xlabel('days')
plt.ylabel('infected')
plt.plot(confirm_df.columns[4:y],sp_list)
plt.plot(confirm_df.columns[4:y],us_list)
plt.legend(['Spain','US'])

# %%
plt.title('Covid-19 cases China vs US')
plt.xlabel('days')
plt.ylabel('infected')
plt.plot(confirm_df.columns[4:y],ch_list)
plt.plot(confirm_df.columns[4:y],us_list)
plt.legend(['China','US'])

# %%
plt.title('Covid-19 cases Japan vs US')
plt.xlabel('days')
plt.ylabel('infected')
plt.plot(confirm_df.columns[4:y],ja_list)
plt.plot(confirm_df.columns[4:y],us_list)
plt.legend(['Japan','US'])

# %%
#The above graph really sums up the difference in what an effective governmental response can mean.
